# %%
import binascii
import numpy as np

s_box = (
    [0x63, 0x7C, 0x77, 0x7B, 0xF2, 0x6B, 0x6F, 0xC5, 0x30, 0x01, 0x67, 0x2B, 0xFE, 0xD7, 0xAB, 0x76],
    [0xCA, 0x82, 0xC9, 0x7D, 0xFA, 0x59, 0x47, 0xF0, 0xAD, 0xD4, 0xA2, 0xAF, 0x9C, 0xA4, 0x72, 0xC0],
    [0xB7, 0xFD, 0x93, 0x26, 0x36, 0x3F, 0xF7, 0xCC, 0x34, 0xA5, 0xE5, 0xF1, 0x71, 0xD8, 0x31, 0x15],
    [0x04, 0xC7, 0x23, 0xC3, 0x18, 0x96, 0x05, 0x9A, 0x07, 0x12, 0x80, 0xE2, 0xEB, 0x27, 0xB2, 0x75],
    [0x09, 0x83, 0x2C, 0x1A, 0x1B, 0x6E, 0x5A, 0xA0, 0x52, 0x3B, 0xD6, 0xB3, 0x29, 0xE3, 0x2F, 0x84],
    [0x53, 0xD1, 0x00, 0xED, 0x20, 0xFC, 0xB1, 0x5B, 0x6A, 0xCB, 0xBE, 0x39, 0x4A, 0x4C, 0x58, 0xCF],
    [0xD0, 0xEF, 0xAA, 0xFB, 0x43, 0x4D, 0x33, 0x85, 0x45, 0xF9, 0x02, 0x7F, 0x50, 0x3C, 0x9F, 0xA8],
    [0x51, 0xA3, 0x40, 0x8F, 0x92, 0x9D, 0x38, 0xF5, 0xBC, 0xB6, 0xDA, 0x21, 0x10, 0xFF, 0xF3, 0xD2],
    [0xCD, 0x0C, 0x13, 0xEC, 0x5F, 0x97, 0x44, 0x17, 0xC4, 0xA7, 0x7E, 0x3D, 0x64, 0x5D, 0x19, 0x73],
    [0x60, 0x81, 0x4F, 0xDC, 0x22, 0x2A, 0x90, 0x88, 0x46, 0xEE, 0xB8, 0x14, 0xDE, 0x5E, 0x0B, 0xDB],
    [0xE0, 0x32, 0x3A, 0x0A, 0x49, 0x06, 0x24, 0x5C, 0xC2, 0xD3, 0xAC, 0x62, 0x91, 0x95, 0xE4, 0x79],
    [0xE7, 0xC8, 0x37, 0x6D, 0x8D, 0xD5, 0x4E, 0xA9, 0x6C, 0x56, 0xF4, 0xEA, 0x65, 0x7A, 0xAE, 0x08],
    [0xBA, 0x78, 0x25, 0x2E, 0x1C, 0xA6, 0xB4, 0xC6, 0xE8, 0xDD, 0x74, 0x1F, 0x4B, 0xBD, 0x8B, 0x8A],
    [0x70, 0x3E, 0xB5, 0x66, 0x48, 0x03, 0xF6, 0x0E, 0x61, 0x35, 0x57, 0xB9, 0x86, 0xC1, 0x1D, 0x9E],
    [0xE1, 0xF8, 0x98, 0x11, 0x69, 0xD9, 0x8E, 0x94, 0x9B, 0x1E, 0x87, 0xE9, 0xCE, 0x55, 0x28, 0xDF],
    [0x8C, 0xA1, 0x89, 0x0D, 0xBF, 0xE6, 0x42, 0x68, 0x41, 0x99, 0x2D, 0x0F, 0xB0, 0x54, 0xBB, 0x16]
)
barnsley= [
    [ 0     ,  0    ,  0     , 0.16  , 0   , 0    , 0.1 ],
    [ 0.85  ,  0.04 ,  0.04  , 0.85  , 0   , 1.6  , 0.3 ],
    [ 0.2   ,  0.26 ,  0.23  , 0.22  , 0   , 1.6  , 0.4 ],
    [-0.15  ,  0.28 ,  0.26  , 0.24  , 0   , 0.44 , 0.2 ],
]


def bytes(integer):
    return divmod(integer, 0x10)

def SubBox(a):
    output = [None] * len(a)
    for x in range(len(a)):
        high, low = bytes(a[x])
        output[x]=s_box[high][low]
    return output

def gf_mul(a, b, mod=0x1B):
  p = 0
  for i in range(8):
    if (b & 1) != 0:
      p ^= a
    high_bit_set = a & 0x80
    a <<= 1
    if high_bit_set != 0:
      a ^= mod
      a = a % 256
    b >>= 1
  print(p)

def Ord(a): #From Plain to Ordinal
    return [ord(c) for c in a] 

def Hex(a): #To Hex Number
    return [hex(c) for c in a] 

def Int(a): #To Integer from Hex
    return [int(c,0) for c in a] 

def SBox(a): #Substitution Box
    
    return result

def ShiftRow(a):
    count=0
    w, h = 4, 4;
    output = [None] * len(a)
    
    s = [[0 for x in range(w)] for y in range(h)] 
    for x in range(4):
        for y in range(4):
            s[x][y]=a[count]
            count=count+1 
    s[1][0], s[1][1], s[1][2], s[1][3] = s[1][1], s[1][2], s[1][3], s[1][0]
    s[2][0], s[2][1], s[2][2], s[2][3] = s[2][2], s[2][3], s[2][0], s[2][1]
    s[3][0], s[3][1], s[3][2], s[3][3] = s[3][3], s[3][0], s[3][1], s[3][2]

    count=0
    for x in range(4):
        for y in range(4):
            output[count]=s[x][y]
            count=count+1
    return output

def galoisMult(a, b):
    p = 0
    hiBitSet = 0
    for i in range(8):
        if b & 1 == 1:
            p ^= a
        hiBitSet = a & 0x80
        a <<= 1
        if hiBitSet == 0x80:
            a ^= 0x1b
        b >>= 1
    return p % 256


def mixColumn(a):
    w, h = 4, 4;
    column= [0 for x in range(w)]
    temp = a.copy()
    
    column[0] = galoisMult(temp[0],2) ^ galoisMult(temp[3],1) ^ \
                galoisMult(temp[2],1) ^ galoisMult(temp[1],3)
    column[1] = galoisMult(temp[1],2) ^ galoisMult(temp[0],1) ^ \
                galoisMult(temp[3],1) ^ galoisMult(temp[2],3)
    column[2] = galoisMult(temp[2],2) ^ galoisMult(temp[1],1) ^ \
                galoisMult(temp[0],1) ^ galoisMult(temp[3],3)
    column[3] = galoisMult(temp[3],2) ^ galoisMult(temp[2],1) ^ \
                galoisMult(temp[1],1) ^ galoisMult(temp[0],3)
    return column

def mixColumns(a):
    count=0
    w, h = 4, 4;
    c1, c2, c3, c4=0, 0, 0, 0
    column1= [0 for x in range(w)]
    column2= [0 for x in range(w)]
    column3= [0 for x in range(w)] 
    column4= [0 for x in range(w)]

    for x in range(4):
        for y in range(4):
            if y==0:
                column1[c1]=a[count]
                c1=c1+1
            elif y==1:
                column2[c2]=a[count]
                c2=c2+1
            elif y==2:
                column3[c3]=a[count]
                c3=c3+1
            else:
                column4[c4]=a[count]
                c4=c4+1
            count=count+1
    column1=mixColumn(column1)
    column2=mixColumn(column2)
    column3=mixColumn(column3)
    column4=mixColumn(column1)
    output = [None] * len(a)
    count=0
    c1, c2, c3, c4=0, 0, 0, 0
    for x in range(16):
        if (x%4)==0:
            output[count]=column1[c1]
            c1=c1+1
        elif (x%4)==1:
            output[count]=column2[c2]
            c2=c2+1
        elif (x%4)==2:
            output[count]=column3[c3]
            c3=c3+1
        else:
            output[count]=column4[c4]
            c4=c4+1
        count=count+1
    return output

def InvShiftRow(a):
    count=0
    w, h = 4, 4;
    s = [[0 for x in range(w)] for y in range(h)] 
    for x in range(4):
        for y in range(4):
            s[x][y]=a[count]
            count=count+1 
    s[1][0], s[1][1], s[1][2], s[1][3] = s[1][3], s[1][0], s[1][1], s[1][2]
    s[2][0], s[2][1], s[2][2], s[2][3] = s[2][2], s[2][3], s[2][0], s[2][1]
    s[3][0], s[3][1], s[3][2], s[3][3] = s[3][1], s[3][2], s[3][3], s[3][0]
    return s

def AddRoundKey(a,b):
    output = [None] * len(a)
    s=int(len(a))
    n=0
    for x in range(s):
        n=n+1
        if n>=len(b):
            n=n-len(b)
        output[x]=a[x]^b[n]
    return output
    
def IFS(a,b):
    output = [None] * len(a)
    i=0
    s=int((len(a)*0.5))
    for x in range(s):
        if x>=len(b):
            n=x-len(b)
        else:
            n=x
        check=b[n]/128
        result=0
        for j in range(s):
            barnsleySelect=(barnsley[j][6])
            if check>barnsleySelect:
                check=check-barnsleySelect
            else:
                print("Barnsley",j)
                print("x'=((",a[i],"*",barnsley[j][0],")+(",a[i+1],"*",barnsley[j][1],")+",barnsley[j][4],")mod 128")
                print("y'=((",a[i],"*",barnsley[j][2],")+(",a[i+1],"*",barnsley[j][3],")+",barnsley[j][5],")mod 128")
                break
        tempCipherX=int(((a[i]*barnsley[j][0])+(a[i+1]*barnsley[j][1])+barnsley[j][4]) % 128)
        tempCipherY=int(((a[i]*barnsley[j][2])+(a[i+1]*barnsley[j][3])+barnsley[j][5]) % 128)
        print("x'=",tempCipherX)
        output[i]=tempCipherX
        print("y'=",tempCipherY,"\n")
        output[i+1]=tempCipherY
        i=i+2
    return output 

def Output(a):
    output = [None] * len(a)
    for x in range(len(a)):
        output[x]=chr(a[x])
    return output

def Avalanche(a):
    Testing=0
    for x in range(len(a)):
        Testing = int(str(Testing)+ str(a[x]))    
    return bin(Testing)

# %%
Text = 0x63
Key = "T35tin9"
PlainText = "Lorfm ipsum dolo"

CipherText=Ord(PlainText)

CipherText=Hex(CipherText)
if isinstance(CipherText[0], int)==0:
    CipherText=Int(CipherText)
    print("PlainText=",CipherText)
    
KeyC=Ord(Key)
KeyC=Hex(KeyC)
if isinstance(KeyC[0], int)==0:
    KeyC=Int(KeyC)
    print("Key=",KeyC,"\n") 
    
CipherText=SubBox(CipherText)
print("Substitution box=", CipherText)

CipherText=ShiftRow(CipherText)
print("Shift Row=",CipherText)

CipherText=mixColumns(CipherText)
print("Mix Columns=", CipherText)

CipherText=AddRoundKey(CipherText,KeyC)
print("Add Round Key=",CipherText)

CipherText=IFS(CipherText,KeyC)
print("IFS=",CipherText)
# Out:
# PlainText= [76, 111, 114, 102, 109, 32, 105, 112, 115, 117, 109, 32, 100, 111, 108, 111]
# Key= [84, 51, 53, 116, 105, 110, 57]
#
# Substitution box= [41, 168, 64, 51, 60, 183, 249, 81, 143, 157, 60, 183, 67, 168, 80, 168]
# Shift Row= [41, 168, 64, 51, 183, 249, 81, 60, 60, 183, 143, 157, 168, 67, 168, 80]
# Mix Columns= [4, 175, 84, 125, 176, 192, 192, 203, 5, 225, 247, 104, 187, 43, 85, 212]
# Add Round Key= [55, 154, 32, 20, 222, 249, 148, 248, 48, 149, 158, 6, 130, 127, 102, 225]
# Barnsley 2
# x'=(( 55 * 0.2 )+( 154 * 0.26 )+ 0 )mod 128
# y'=(( 55 * 0.23 )+( 154 * 0.22 )+ 1.6 )mod 128
# x'= 51
# y'= 48
#
# Barnsley 1
# x'=(( 32 * 0.85 )+( 20 * 0.04 )+ 0 )mod 128
# y'=(( 32 * 0.04 )+( 20 * 0.85 )+ 1.6 )mod 128
# x'= 28
# y'= 19
#
# Barnsley 2
# x'=(( 222 * 0.2 )+( 249 * 0.26 )+ 0 )mod 128
# y'=(( 222 * 0.23 )+( 249 * 0.22 )+ 1.6 )mod 128
# x'= 109
# y'= 107
#
# Barnsley 3
# x'=(( 148 * -0.15 )+( 248 * 0.28 )+ 0 )mod 128
# y'=(( 148 * 0.26 )+( 248 * 0.24 )+ 0.44 )mod 128
# ...

# %%
#Avalanche Test
print(CipherText)
Avalanche2=Avalanche(CipherText)
print("Cipher1 =",Avalanche1)
print("Cipher2 =",Avalanche2)
AV=0
for index, (value1, value2) in enumerate(zip(Avalanche1, Avalanche2)):
    if value1==value2:
        AV=AV+1
print((AV+2)/141)
# Out:
# [51, 48, 28, 19, 109, 107, 47, 98, 34, 48, 105, 42, 59, 59, 78, 74]
# Cipher1 = 0b1101101111111110011011101111110001101001011000000001000000101110010001101110000011110011111111110100111100
# Cipher2 = 0b10011110101001001100100010000101011010100000110101001001010000011010110000100000010110000000111010111101001000110010
# 0.3900709219858156

# %%
Test11=[55, 154, 32, 20, 222, 249, 148, 248, 48, 149, 158, 6, 130, 127, 102, 225]
Test12=[55, 56, 32, 20, 222, 168, 148, 248, 48, 196, 158, 6, 130, 140, 102, 225]
Avalanche2=Avalanche(Test12)
AV=0
for index, (value1, value2) in enumerate(zip(Avalanche11, Avalanche12)):
    if value1==value2:
        AV=AV+1
print((AV)/(len(Avalanche1)-2)*100)

Test21=[143, 38, 208, 237, 71, 114, 220, 100, 170, 79, 163, 219, 58, 35, 131, 90]
Test22=[143, 176, 208, 237, 71, 150, 220, 100, 170, 61, 163, 219, 58, 81, 131, 90]
Avalanche1=Avalanche(Test21)
Avalanche2=Avalanche(Test22)
AV=0
for index, (value1, value2) in enumerate(zip(Avalanche1, Avalanche2)):
    if value1==value2:
        AV=AV+1
print((AV)/len(Avalanche1)*100)


Test31=[21, 176, 233, 194, 235, 72, 22, 37, 28, 125, 3, 113, 99, 186, 195, 71]
Test32=[74, 176, 233, 222, 73, 72, 22, 37, 190, 125, 3, 207, 158, 186, 195, 71]
Avalanche1=Avalanche(Test31)
Avalanche2=Avalanche(Test32)
AV=0
for index, (value1, value2) in enumerate(zip(Avalanche1, Avalanche2)):
    if value1==value2:
        AV=AV+1
print((AV)/len(Avalanche1)*100)

Test41=[27, 125, 102, 147, 159, 241, 128, 88, 57, 39, 31, 70, 151, 100, 177, 247]
Test42=[185, 125, 102, 45, 98, 241, 128, 88, 102, 39, 31, 90, 53, 100, 177, 247]
Avalanche1=Avalanche(Test11)
Avalanche1=Avalanche(Test41)
Avalanche2=Avalanche(Test42)
AV=0
for index, (value1, value2) in enumerate(zip(Avalanche1, Avalanche2)):
    if value1==value2:
        AV=AV+1
print((AV)/len(Avalanche1)*100)
# Out:
# 62.264150943396224
# 51.798561151079134
# 50.0
# 43.57142857142857
